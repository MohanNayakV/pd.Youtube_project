# %%
#project 8 Youtube Channel Dataset

# %%
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv('C:\\Users\\Mohan\\Desktop\\Project CSV\\top-5000-youtube-channels.csv')

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
#1. Display All rows Except the last 5 rows using head method
data.head(10)
# Out:
#    Rank Grade                Channel name Video Uploads Subscribers  \
# 0   1st  A++                       Zee TV         82757    18752951
# 1   2nd  A++                     T-Series         12661    61196302
# 2   3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3   4th  A++                    SET India         27323    31180559
# 4   5th  A++                          WWE         36756    32852346
# 5   6th  A++                   Movieclips         30243    17149705
# 6   7th  A++                   netd müzik          8500    11373567
# 7   8th  A++        ABS-CBN Entertainment        100147    12149206
# 8   9th  A++              Ryan ToysReview          1140    16082927
# 9  10th  A++                  Zee Marathi         74607     2841811
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433
# 5  16618094724
# 6  23898730764
# 7  17202609850
# 8  24518098041
# 9   2591830307

# %%
data.head(-5)
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# ...       ...   ...                               ...           ...
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel           208
# 4991  4,992nd   B+               Toys to Learn Colors            11
# 4992  4,993rd   B+                              КАZКА            25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…          1055
# 4994  4,995th   B+                      Wings Marathi          1735
#
#      Subscribers  Video views
# 0       18752951  20869786591
# 1       61196302  47548839843
# 2       19238251   9793305082
# ...

# %%
#2. Display All Rows Except the first 5 rows using tail method
data.tail()
# Out:
#          Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996th   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+         Mastersaint           110     3265735    311758426
# 4998  4,999th   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000th   B+           SehatAQUA           254       21172     73312511

# %%
data.tail(10)
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel           208
# 4991  4,992nd   B+               Toys to Learn Colors            11
# 4992  4,993rd   B+                              КАZКА            25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…          1055
# 4994  4,995th   B+                      Wings Marathi          1735
# 4995  4,996th   B+                     Uras Benlioğlu           706
# 4996  4,997th   B+                  HI-TECH MUSIC LTD           797
# 4997  4,998th   B+                        Mastersaint           110
# 4998  4,999th   B+                     Bruce McIntosh          3475
# 4999  5,000th   B+                          SehatAQUA           254
#
#      Subscribers  Video views
# 4990         --     127185704
# 4991      663114    141933264
# 4992      131766     74304638
# 4993     1586835    371299166
# 4994     1099659    346175699
# 4995     2072942    441202795
# ...

# %%
data.tail(-5)
# Out:
#          Rank Grade           Channel name Video Uploads Subscribers  \
# 5         6th  A++              Movieclips         30243    17149705
# 6         7th  A++              netd müzik          8500    11373567
# 7         8th  A++   ABS-CBN Entertainment        100147    12149206
# 8         9th  A++         Ryan ToysReview          1140    16082927
# 9        10th  A++             Zee Marathi         74607     2841811
# ...       ...   ...                    ...           ...         ...
# 4995  4,996th   B+          Uras Benlioğlu           706     2072942
# 4996  4,997th   B+       HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+             Mastersaint           110     3265735
# 4998  4,999th   B+          Bruce McIntosh          3475       32990
# 4999  5,000th   B+               SehatAQUA           254       21172
#
#       Video views
# 5     16618094724
# 6     23898730764
# 7     17202609850
# 8     24518098041
# 9      2591830307
# ...           ...
# ...

# %%
#3. Find shape of our dataset (Number of rows and columns)
data.shape
# Out:
# (5000, 6)

# %%
print("Number of Rows",data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 5000
# Number of Columns 6

# %%
#4.Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
#5. Get Overall Statistics About The Dataframe
pd.options.display.float_format = '(2f)'.format

# %%
data.describe()
# Out:
#        Video views
# count         (2f)
# mean          (2f)
# std           (2f)
# min           (2f)
# 25%           (2f)
# 50%           (2f)
# 75%           (2f)
# max           (2f)

# %%
pd.options.display.float_format = '(2f)'.format

# %%
data.describe()
# Out:
#        Video views
# count         (2f)
# mean          (2f)
# std           (2f)
# min           (2f)
# 25%           (2f)
# 50%           (2f)
# 75%           (2f)
# max           (2f)

# %%
#6. Data Cleaning  (Replace '--'  to NaN)
data.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
import numpy as np

# %%
data=data.replace('--',np.nan,regex=True)

# %%
data.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
#7. Check Null Values In The Dataset
data.isnull()
# Out:
#        Rank  Grade  Channel name  Video Uploads  Subscribers  Video views
# 0     False  False         False          False        False        False
# 1     False  False         False          False        False        False
# 2     False  False         False          False        False        False
# 3     False  False         False          False        False        False
# 4     False  False         False          False        False        False
# ...     ...    ...           ...            ...          ...          ...
# 4995  False  False         False          False        False        False
# 4996  False  False         False          False        False        False
# 4997  False  False         False          False        False        False
# 4998  False  False         False          False        False        False
# 4999  False  False         False          False        False        False
#
# [5000 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Rank               0
# Grade              0
# Channel name       0
# Video Uploads      6
# Subscribers      387
# Video views        0
# dtype: int64

# %%
per_missing = data.isnull().sum() + 100/len(data)

# %%
per_missing
# Out:
# Rank            (2f)
# Grade           (2f)
# Channel name    (2f)
# Video Uploads   (2f)
# Subscribers     (2f)
# Video views     (2f)
# dtype: float64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.dropna(axis=0,inplace=True)

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
#8. Data Cleaning [ Rank Column ]
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data.tail()
# Out:
#          Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996th   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+         Mastersaint           110     3265735    311758426
# 4998  4,999th   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000th   B+           SehatAQUA           254       21172     73312511

# %%
data.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
data['Rank']=data['Rank'].str[0:-2]

# %%
data.head(10)
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1  A++                       Zee TV         82757    18752951
# 1    2  A++                     T-Series         12661    61196302
# 2    3  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4  A++                    SET India         27323    31180559
# 4    5  A++                          WWE         36756    32852346
# 5    6  A++                   Movieclips         30243    17149705
# 6    7  A++                   netd müzik          8500    11373567
# 7    8  A++        ABS-CBN Entertainment        100147    12149206
# 8    9  A++              Ryan ToysReview          1140    16082927
# 9   10  A++                  Zee Marathi         74607     2841811
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433
# 5  16618094724
# 6  23898730764
# 7  17202609850
# 8  24518098041
# 9   2591830307

# %%
data.tail(10)
# Out:
#        Rank Grade                      Channel name Video Uploads Subscribers  \
# 4989  4,990   B+                             Kukuli           219      660742
# 4991  4,992   B+               Toys to Learn Colors            11      663114
# 4992  4,993   B+                              КАZКА            25      131766
# 4993  4,994   B+   United CUBE (CUBE Entertainment…          1055     1586835
# 4994  4,995   B+                      Wings Marathi          1735     1099659
# 4995  4,996   B+                     Uras Benlioğlu           706     2072942
# 4996  4,997   B+                  HI-TECH MUSIC LTD           797     1055091
# 4997  4,998   B+                        Mastersaint           110     3265735
# 4998  4,999   B+                     Bruce McIntosh          3475       32990
# 4999  5,000   B+                          SehatAQUA           254       21172
#
#       Video views
# 4989    437197125
# 4991    141933264
# 4992     74304638
# 4993    371299166
# ...

# %%
data['Rank']=data['Rank'].str.replace(',','')

# %%
data.head(10)
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1  A++                       Zee TV         82757    18752951
# 1    2  A++                     T-Series         12661    61196302
# 2    3  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4  A++                    SET India         27323    31180559
# 4    5  A++                          WWE         36756    32852346
# 5    6  A++                   Movieclips         30243    17149705
# 6    7  A++                   netd müzik          8500    11373567
# 7    8  A++        ABS-CBN Entertainment        100147    12149206
# 8    9  A++              Ryan ToysReview          1140    16082927
# 9   10  A++                  Zee Marathi         74607     2841811
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433
# 5  16618094724
# 6  23898730764
# 7  17202609850
# 8  24518098041
# 9   2591830307

# %%
data.tail(10)
# Out:
#       Rank Grade                      Channel name Video Uploads Subscribers  \
# 4989  4990   B+                             Kukuli           219      660742
# 4991  4992   B+               Toys to Learn Colors            11      663114
# 4992  4993   B+                              КАZКА            25      131766
# 4993  4994   B+   United CUBE (CUBE Entertainment…          1055     1586835
# 4994  4995   B+                      Wings Marathi          1735     1099659
# 4995  4996   B+                     Uras Benlioğlu           706     2072942
# 4996  4997   B+                  HI-TECH MUSIC LTD           797     1055091
# 4997  4998   B+                        Mastersaint           110     3265735
# 4998  4999   B+                     Bruce McIntosh          3475       32990
# 4999  5000   B+                          SehatAQUA           254       21172
#
#       Video views
# 4989    437197125
# 4991    141933264
# 4992     74304638
# 4993    371299166
# 4994    346175699
# ...

# %%
data['Rank']=data['Rank'].str.replace(',','').astype('int')

# %%
data.dtypes
# Out:
# Rank              int32
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
#10. Data Cleaning [ Grade Column ]
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
data.sort_values(by='Video Uploads')
# Out:
#       Rank Grade               Channel name Video Uploads Subscribers  \
# 4975  4976   B+                  Funny Kids             1      150091
# 4100  4101   B+             DenzelCurryVEVO             1        8012
# 4474  4475   B+                   hyghhopes             1       15325
# 628    629    A                  cocoz toon             1     2162992
# 2404  2405   B+          ItsHARSH007 Gaming             1       23499
# ...    ...   ...                        ...           ...         ...
# 1148  1149   A-      WildBrain em Português           995      985848
# 4064  4065   B+                  AmmA Music           995     1317578
# 1748  1749   A-                 SBS Culture         99544      322193
# 1228  1229   A-      Saas Bahu Aur Betiyaan          9987     1681614
# 1878  1879   A-   Bhoot Pret Manu Bhaiya Ji           999      162291
#
#       Video views
# 4975     21933876
# 4100     25878252
# 4474     14842098
# 628     333012122
# 2404           75
# ...

# %%
data.sort_values(by='Video Uploads',ascending=False)
# Out:
#       Rank Grade               Channel name Video Uploads Subscribers  \
# 1878  1879   A-   Bhoot Pret Manu Bhaiya Ji           999      162291
# 1228  1229   A-      Saas Bahu Aur Betiyaan          9987     1681614
# 1748  1749   A-                 SBS Culture         99544      322193
# 1148  1149   A-      WildBrain em Português           995      985848
# 4064  4065   B+                  AmmA Music           995     1317578
# ...    ...   ...                        ...           ...         ...
# 4975  4976   B+                  Funny Kids             1      150091
# 4474  4475   B+                   hyghhopes             1       15325
# 628    629    A                  cocoz toon             1     2162992
# 4100  4101   B+             DenzelCurryVEVO             1        8012
# 2404  2405   B+          ItsHARSH007 Gaming             1       23499
#
#       Video views
# 1878     54727215
# 1228    820102614
# 1748    402883303
# 1148    388267495
# 4064   1298288901
# ...

# %%
#11. Find Average Views For Each Channel
data.sort_values(by='Video Uploads',ascending=False).head()
# Out:
#       Rank Grade               Channel name Video Uploads Subscribers  \
# 1878  1879   A-   Bhoot Pret Manu Bhaiya Ji           999      162291
# 1228  1229   A-      Saas Bahu Aur Betiyaan          9987     1681614
# 1748  1749   A-                 SBS Culture         99544      322193
# 1148  1149   A-      WildBrain em Português           995      985848
# 4064  4065   B+                  AmmA Music           995     1317578
#
#       Video views
# 1878     54727215
# 1228    820102614
# 1748    402883303
# 1148    388267495
# 4064   1298288901

# %%
#13. Find the corelation matrix
data.corr()
# Out:
#              Rank  Video views
# Rank         (2f)         (2f)
# Video views  (2f)         (2f)
